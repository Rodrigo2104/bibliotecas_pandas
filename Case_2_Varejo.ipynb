# %% [markdown]
# <a href="https://colab.research.google.com/github/Rodrigo2104/bibliotecas_pandas/blob/main/Case_2_Varejo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Screenshot 2023-05-01 112838.jpg](data:image/jpeg;base64,...)

# %%
import pandas as pd
import seaborn as sns

# %%
vendas = pd.read_excel("/content/varejo.xlsx")
vendas.head()
# Out:
#    idcompra idcanalvenda bandeira       Data     Preço  Preço_com_frete  \
# 0    393835       Mobile        A 2023-03-05  1582.560          791.280
# 1    411885       Mobile        A 2023-03-17   679.200          679.200
# 2    437305       Mobile        A 2023-03-06    35.920           37.512
# 3    440055          APP        A 2023-01-13  2239.416         2239.416
# 4    455795       Mobile        B 2023-03-31  1743.200         1785.112
#
#        Nome_Departamento estado  cliente_Log
# 0  Telefones e Celulares     SP        15042
# 1                Tablets     SP        17590
# 2                  Bebes     SP        15478
# 3       TVs e Acessorios     SP         2933
# 4        Esporte e Lazer     RS        19790

# %%
vendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80228 entries, 0 to 80227
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   idcompra           80228 non-null  int64
#  1   idcanalvenda       80228 non-null  object
#  2   bandeira           80228 non-null  object
#  3   Data               80228 non-null  datetime64[ns]
#  4   Preço              79926 non-null  float64
#  5   Preço_com_frete    80228 non-null  float64
#  6   Nome_Departamento  80228 non-null  object
#  7   estado             79926 non-null  object
#  8   cliente_Log        80228 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(4)
# memory usage: 5.5+ MB

# %%
a=vendas.groupby("idcanalvenda").idcompra.nunique()

# %%
print(a)
# Out:
# idcanalvenda
# APP             139
# Aplicativo    21425
# Internet      24515
# Mobile        24732
# Name: idcompra, dtype: int64

# %%
vendas.groupby("Nome_Departamento").idcompra.nunique()
# Out:
# Nome_Departamento
# Acessorios e Inovacoes     3548
# Alimentos                     2
# Ar e Ventilacao             951
# Audio                      1794
# Automotivo                  895
# Bebes                      4531
# Beleza e Saude             4626
# Brinquedos                 1320
# Cama, Mesa e Banho          153
# Casa e Construcao           263
# Cine e Foto                  11
# Decoracao                   134
# Eletrodomesticos          10501
# Eletroportateis            9593
# Esporte e Lazer             531
# Ferramentas                1111
# Games                       764
# Informatica                5290
# Instrumentos Musicais         1
# Linha Industrial             86
# Malas e Mochilas            114
# Moda                          3
# Moveis                     4175
# Perfumaria                  624
# Pet Shop                     43
# Produtos de Limpeza         713
# Relogios                    134
# TV e Video                    5
# ...

# %%
vendas["idcanalvenda"]=vendas["idcanalvenda"].str.replace("APP","Aplicativo")

# %%
vendas["Nome_Departamento"]=vendas["Nome_Departamento"].str.replace(" ","_")

# %%
vendas["idcanalvenda"] = vendas["idcanalvenda"].str.replace("APP", "Aplicativo")
vendas.groupby("idcanalvenda").idcompra.nunique()
# Out:
# idcanalvenda
# Aplicativo    21539
# Internet      24515
# Mobile        24732
# Name: idcompra, dtype: int64

# %%
vendas[vendas["estado"].isnull()]
# Out:
#        idcompra idcanalvenda bandeira       Data  Preço  Preço_com_frete  \
# 96       382380     Internet        A 2023-04-26    NaN          879.200
# 284      346055     Internet        A 2023-03-23    NaN           87.648
# 402      172555       Mobile        A 2023-03-19    NaN          135.840
# 411      446380       Mobile        A 2023-03-09    NaN         1703.120
# 770       40425       Mobile        B 2023-04-21    NaN         1759.200
# ...         ...          ...      ...        ...    ...              ...
# 78610    399680   Aplicativo        A 2023-04-19    NaN          339.912
# 78718    320895       Mobile        B 2023-01-20    NaN         1000.800
# 79465    389240   Aplicativo        A 2023-01-14    NaN          279.200
# 79548    124585       Mobile        A 2023-04-21    NaN         2051.240
# 80016    104235   Aplicativo        A 2023-04-17    NaN         1199.200
#
#            Nome_Departamento estado  cliente_Log
# ...

# %%
vendas_nn=vendas.dropna()

# %%
vendas_nn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 79926 entries, 0 to 80227
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   idcompra           79926 non-null  int64
#  1   idcanalvenda       79926 non-null  object
#  2   bandeira           79926 non-null  object
#  3   Data               79926 non-null  datetime64[ns]
#  4   Preço              79926 non-null  float64
#  5   Preço_com_frete    79926 non-null  float64
#  6   Nome_Departamento  79926 non-null  object
#  7   estado             79926 non-null  object
#  8   cliente_Log        79926 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(4)
# memory usage: 6.1+ MB

# %%
vendas["estado"].fillna("MS", inplace=True)
# Out:
# <ipython-input-13-959a4bdfbea9>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   vendas["estado"].fillna("MS", inplace=True)

# %%
vendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80228 entries, 0 to 80227
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   idcompra           80228 non-null  int64
#  1   idcanalvenda       80228 non-null  object
#  2   bandeira           80228 non-null  object
#  3   Data               80228 non-null  datetime64[ns]
#  4   Preço              79926 non-null  float64
#  5   Preço_com_frete    80228 non-null  float64
#  6   Nome_Departamento  80228 non-null  object
#  7   estado             80228 non-null  object
#  8   cliente_Log        80228 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(4)
# memory usage: 5.5+ MB

# %%
vendas.groupby("bandeira").idcompra.nunique()
# Out:
# bandeira
# A    27679
# B    38483
# Name: idcompra, dtype: int64

# %%
vendas.groupby("Nome_Departamento").idcompra.nunique()
# Out:
# Nome_Departamento
# Acessorios_e_Inovacoes     3548
# Alimentos                     2
# Ar_e_Ventilacao             951
# Audio                      1794
# Automotivo                  895
# Bebes                      4531
# Beleza_e_Saude             4626
# Brinquedos                 1320
# Cama,_Mesa_e_Banho          153
# Casa_e_Construcao           263
# Cine_e_Foto                  11
# Decoracao                   134
# Eletrodomesticos          10501
# Eletroportateis            9593
# Esporte_e_Lazer             531
# Ferramentas                1111
# Games                       764
# Informatica                5290
# Instrumentos_Musicais         1
# Linha_Industrial             86
# Malas_e_Mochilas            114
# Moda                          3
# Moveis                     4175
# Perfumaria                  624
# Pet_Shop                     43
# Produtos_de_Limpeza         713
# Relogios                    134
# TV_e_Video                    5
# ...

# %%
vendas.groupby("estado").idcompra.nunique()
# Out:
# estado
# AC       10
# AL      461
# AM       15
# AP        3
# BA     2028
# CE     1007
# DF     1902
# ES     1254
# GO     1603
# MA      129
# MG    10538
# MS      302
# MT      510
# PA      108
# PB      536
# PE     1632
# PI      247
# PR     2754
# RJ    16213
# RN      463
# RO       15
# RR        7
# RS     4099
# SC     1932
# SE      340
# SP    25962
# TO      101
# Name: idcompra, dtype: int64

# %%
vendas["Nome_Departamento"] = vendas["Nome_Departamento"].str.replace(" ","_")
vendas.groupby("Nome_Departamento").idcompra.nunique()
# Out:
# Nome_Departamento
# Acessorios_e_Inovacoes     3548
# Alimentos                     2
# Ar_e_Ventilacao             951
# Audio                      1794
# Automotivo                  895
# Bebes                      4531
# Beleza_e_Saude             4626
# Brinquedos                 1320
# Cama,_Mesa_e_Banho          153
# Casa_e_Construcao           263
# Cine_e_Foto                  11
# Decoracao                   134
# Eletrodomesticos          10501
# Eletroportateis            9593
# Esporte_e_Lazer             531
# Ferramentas                1111
# Games                       764
# Informatica                5290
# Instrumentos_Musicais         1
# Linha_Industrial             86
# Malas_e_Mochilas            114
# Moda                          3
# Moveis                     4175
# Perfumaria                  624
# Pet_Shop                     43
# Produtos_de_Limpeza         713
# Relogios                    134
# TV_e_Video                    5
# ...

# %%
vendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80228 entries, 0 to 80227
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   idcompra           80228 non-null  int64
#  1   idcanalvenda       80228 non-null  object
#  2   bandeira           80228 non-null  object
#  3   Data               80228 non-null  datetime64[ns]
#  4   Preço              79926 non-null  float64
#  5   Preço_com_frete    80228 non-null  float64
#  6   Nome_Departamento  80228 non-null  object
#  7   estado             80228 non-null  object
#  8   cliente_Log        80228 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(4)
# memory usage: 5.5+ MB

# %%
vendas[vendas["estado"].isnull()]
# Out:
# Empty DataFrame
# Columns: [idcompra, idcanalvenda, bandeira, Data, Preço, Preço_com_frete, Nome_Departamento, estado, cliente_Log]
# Index: []

# %%
vendas_sem_nulos = vendas.dropna()
vendas_sem_nulos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 79926 entries, 0 to 80227
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   idcompra           79926 non-null  int64
#  1   idcanalvenda       79926 non-null  object
#  2   bandeira           79926 non-null  object
#  3   Data               79926 non-null  datetime64[ns]
#  4   Preço              79926 non-null  float64
#  5   Preço_com_frete    79926 non-null  float64
#  6   Nome_Departamento  79926 non-null  object
#  7   estado             79926 non-null  object
#  8   cliente_Log        79926 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(4)
# memory usage: 6.1+ MB

# %%
vendas["estado"] = vendas["estado"].fillna("MS")

# %%
vendas["estado"].fillna("MS", inplace=True)
# Out:
# <ipython-input-23-959a4bdfbea9>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   vendas["estado"].fillna("MS", inplace=True)

# %%
vendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80228 entries, 0 to 80227
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   idcompra           80228 non-null  int64
#  1   idcanalvenda       80228 non-null  object
#  2   bandeira           80228 non-null  object
#  3   Data               80228 non-null  datetime64[ns]
#  4   Preço              79926 non-null  float64
#  5   Preço_com_frete    80228 non-null  float64
#  6   Nome_Departamento  80228 non-null  object
#  7   estado             80228 non-null  object
#  8   cliente_Log        80228 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(4)
# memory usage: 5.5+ MB

# %%
media_preco = vendas["Preço"].mean()

vendas["Preço"].fillna(media_preco, inplace= True)
# Out:
# <ipython-input-25-10b1a815d9f3>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   vendas["Preço"].fillna(media_preco, inplace= True)

# %%
media_preco
# Out:
# np.float64(906.5891285439033)

# %%
vendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80228 entries, 0 to 80227
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   idcompra           80228 non-null  int64
#  1   idcanalvenda       80228 non-null  object
#  2   bandeira           80228 non-null  object
#  3   Data               80228 non-null  datetime64[ns]
#  4   Preço              80228 non-null  float64
#  5   Preço_com_frete    80228 non-null  float64
#  6   Nome_Departamento  80228 non-null  object
#  7   estado             80228 non-null  object
#  8   cliente_Log        80228 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(4)
# memory usage: 5.5+ MB

# %%
mediana_preco = vendas["Preço"].median()
mediana_preco
# Out:
# 532.448

# %%
vendas.head()
# Out:
#    idcompra idcanalvenda bandeira       Data     Preço  Preço_com_frete  \
# 0    393835       Mobile        A 2023-03-05  1582.560          791.280
# 1    411885       Mobile        A 2023-03-17   679.200          679.200
# 2    437305       Mobile        A 2023-03-06    35.920           37.512
# 3    440055   Aplicativo        A 2023-01-13  2239.416         2239.416
# 4    455795       Mobile        B 2023-03-31  1743.200         1785.112
#
#        Nome_Departamento estado  cliente_Log
# 0  Telefones_e_Celulares     SP        15042
# 1                Tablets     SP        17590
# 2                  Bebes     SP        15478
# 3       TVs_e_Acessorios     SP         2933
# 4        Esporte_e_Lazer     RS        19790

# %%
vendas[["Preço","Preço_com_frete"]].describe()
# Out:
#               Preço  Preço_com_frete
# count  80228.000000     80228.000000
# mean     906.589129       908.619823
# std     1057.611490      1057.583101
# min        6.320000         6.320000
# 25%      147.920000       150.706000
# 50%      532.448000       535.120000
# 75%     1199.200000      1215.240000
# max    14439.240000     14439.240000

# %%
vendas["Frete"]=vendas["Preço_com_frete"]-vendas["Preço"]

# %%
vendas[["Preço","Preço_com_frete"]].describe()
# Out:
#               Preço  Preço_com_frete
# count  80228.000000     80228.000000
# mean     906.589129       908.619823
# std     1057.611490      1057.583101
# min        6.320000         6.320000
# 25%      147.920000       150.706000
# 50%      532.448000       535.120000
# 75%     1199.200000      1215.240000
# max    14439.240000     14439.240000

# %%
vendas[["Preço","Preço_com_frete", "Frete"]].describe()
# Out:
#               Preço  Preço_com_frete         Frete
# count  80228.000000     80228.000000  80228.000000
# mean     906.589129       908.619823      2.030694
# std     1057.611490      1057.583101     92.799931
# min        6.320000         6.320000  -6799.200000
# 25%      147.920000       150.706000      0.000000
# 50%      532.448000       535.120000      0.000000
# 75%     1199.200000      1215.240000      1.592000
# max    14439.240000     14439.240000  12452.610871

# %%
preco_errado = vendas.query("Preço > Preço_com_frete")

vendas_correto = vendas.query("Preço <= Preço_com_frete")

# %%
vendas_correto.describe()
# Out:
#             idcompra                           Data         Preço  \
# count   79888.000000                          79888  79888.000000
# mean   251006.932831  2023-03-02 02:43:13.110354432    905.450941
# min         0.000000            2023-01-02 00:00:00      6.320000
# 25%    126877.500000            2023-02-01 00:00:00    144.320000
# 50%    251770.000000            2023-03-02 00:00:00    531.240000
# 75%    375871.250000            2023-04-01 00:00:00   1199.200000
# max    723410.000000            2023-04-30 00:00:00  14439.240000
# std    144233.055210                            NaN   1056.303339
#
#        Preço_com_frete   cliente_Log         Frete
# count     79888.000000  79888.000000  79888.000000
# mean        910.367219  13932.167009      4.916278
# min           6.320000      1.000000      0.000000
# 25%         151.128000   6916.000000      0.000000
# 50%         535.200000  13932.000000      0.000000
# 75%        1219.120000  20915.000000      1.592000
# ...

# %%
vendas_correto.head()
# Out:
#    idcompra idcanalvenda bandeira       Data     Preço  Preço_com_frete  \
# 1    411885       Mobile        A 2023-03-17   679.200          679.200
# 2    437305       Mobile        A 2023-03-06    35.920           37.512
# 3    440055   Aplicativo        A 2023-01-13  2239.416         2239.416
# 4    455795       Mobile        B 2023-03-31  1743.200         1785.112
# 5    456225     Internet        A 2023-03-19  1903.200         1903.200
#
#        Nome_Departamento estado  cliente_Log   Frete
# 1                Tablets     SP        17590   0.000
# 2                  Bebes     SP        15478   1.592
# 3       TVs_e_Acessorios     SP         2933   0.000
# 4        Esporte_e_Lazer     RS        19790  41.912
# 5  Telefones_e_Celulares     SP        23742   0.000

# %%
vendas_correto.query("estado == 'SP' and Nome_Departamento=='Bebes' ").describe()
# Out:
#             idcompra                           Data        Preço  \
# count    1779.000000                           1779  1779.000000
# mean   257506.514896  2023-03-03 04:14:09.915683072   127.736711
# min       310.000000            2023-01-02 00:00:00     8.720000
# 25%    130772.500000            2023-02-01 00:00:00    83.920000
# 50%    260485.000000            2023-03-05 00:00:00   106.320000
# 75%    390407.500000            2023-04-01 00:00:00   135.920000
# max    499695.000000            2023-04-30 00:00:00  2311.320000
# std    146108.969307                            NaN   128.115138
#
#        Preço_com_frete   cliente_Log        Frete
# count      1779.000000   1779.000000  1779.000000
# mean        131.054804  13762.876897     3.318093
# min           9.512000     26.000000     0.000000
# 25%          86.952000   6682.500000     1.592000
# 50%         109.512000  13987.000000     1.600000
# 75%         137.512000  20523.500000     3.192000
# ...

# %%
vendas_correto.query("Nome_Departamento == 'Esporte_e_Lazer' and estado == 'SP'").describe()
# Out:
#             idcompra                           Data       Preço  \
# count     191.000000                            191   191.00000
# mean   272904.240838  2023-03-05 02:53:24.188481792  1010.24356
# min      2145.000000            2023-01-02 00:00:00    10.89600
# 25%    162705.000000            2023-02-03 12:00:00   519.20000
# 50%    263305.000000            2023-03-05 00:00:00  1039.20000
# 75%    392710.000000            2023-04-04 12:00:00  1471.20000
# max    497570.000000            2023-04-30 00:00:00  2399.20000
# std    140870.980710                            NaN   620.36360
#
#        Preço_com_frete   cliente_Log       Frete
# count       191.000000    191.000000  191.000000
# mean       1035.426052  14317.968586   25.182492
# min          16.112000    210.000000    0.000000
# 25%         523.200000   7699.000000   14.436000
# 50%        1060.392000  15256.000000   24.520000
# 75%        1499.124000  20637.000000   31.920000
# ...

# %%
vendas_correto.groupby("Nome_Departamento").idcompra.nunique().sort_values(ascending=False)
# Out:
# Nome_Departamento
# Telefones_e_Celulares     14464
# Eletrodomesticos          10466
# Eletroportateis            9530
# TVs_e_Acessorios           5319
# Informatica                5273
# Beleza_e_Saude             4605
# Bebes                      4503
# Moveis                     4155
# Utilidades_Domesticas      3702
# Acessorios_e_Inovacoes     3535
# Audio                      1786
# Tablets                    1763
# Brinquedos                 1304
# Ferramentas                1105
# Ar_e_Ventilacao             948
# Automotivo                  890
# Games                       763
# Produtos_de_Limpeza         712
# Perfumaria                  618
# Esporte_e_Lazer             528
# Casa_e_Construcao           263
# Cama,_Mesa_e_Banho          153
# Decoracao                   134
# Relogios                    134
# Malas_e_Mochilas            113
# Linha_Industrial             86
# Pet_Shop                     43
# Cine_e_Foto                  11
# ...

# %%
vendas_correto.groupby("Nome_Departamento").idcompra.nunique().sort_values(ascending=False)
# Out:
# Nome_Departamento
# Telefones_e_Celulares     14464
# Eletrodomesticos          10466
# Eletroportateis            9530
# TVs_e_Acessorios           5319
# Informatica                5273
# Beleza_e_Saude             4605
# Bebes                      4503
# Moveis                     4155
# Utilidades_Domesticas      3702
# Acessorios_e_Inovacoes     3535
# Audio                      1786
# Tablets                    1763
# Brinquedos                 1304
# Ferramentas                1105
# Ar_e_Ventilacao             948
# Automotivo                  890
# Games                       763
# Produtos_de_Limpeza         712
# Perfumaria                  618
# Esporte_e_Lazer             528
# Casa_e_Construcao           263
# Cama,_Mesa_e_Banho          153
# Decoracao                   134
# Relogios                    134
# Malas_e_Mochilas            113
# Linha_Industrial             86
# Pet_Shop                     43
# Cine_e_Foto                  11
# ...

# %%
vendas_correto.groupby("Nome_Departamento").Preço_com_frete.agg("mean").sort_values(ascending=False).reset_index()
# Out:
#          Nome_Departamento  Preço_com_frete
# 0               TV_e_Video      9847.264000
# 1         TVs_e_Acessorios      2058.703545
# 2              Informatica      2018.255616
# 3         Linha_Industrial      1668.679535
# 4              Cine_e_Foto      1461.082182
# 5    Telefones_e_Celulares      1420.012216
# 6         Eletrodomesticos      1235.415810
# 7          Esporte_e_Lazer      1032.471985
# 8                  Tablets       963.603369
# 9    Instrumentos_Musicais       834.608000
# 10                   Games       739.693437
# 11                  Moveis       670.181693
# 12                   Audio       617.360813
# 13  Acessorios_e_Inovacoes       594.576645
# 14              Automotivo       570.397410
# 15         Ar_e_Ventilacao       309.176420
# 16       Casa_e_Construcao       261.524152
# 17         Eletroportateis       239.742015
# 18                Pet_Shop       236.339163
# 19             Ferramentas       228.956255
# ...

# %%
vendas_correto.groupby("mes").idcompra.agg("count").reset_index()
# Out:
#    mes  idcompra
# 0    1     19901
# 1    2     18941
# 2    3     20894
# 3    4     20152

# %%
round(vendas_correto.groupby("Nome_Departamento")["Preço_com_frete"].agg("mean").sort_values(ascending=False).reset_index(),2)
# Out:
#          Nome_Departamento  Preço_com_frete
# 0               TV_e_Video          9847.26
# 1         TVs_e_Acessorios          2058.70
# 2              Informatica          2018.26
# 3         Linha_Industrial          1668.68
# 4              Cine_e_Foto          1461.08
# 5    Telefones_e_Celulares          1420.01
# 6         Eletrodomesticos          1235.42
# 7          Esporte_e_Lazer          1032.47
# 8                  Tablets           963.60
# 9    Instrumentos_Musicais           834.61
# 10                   Games           739.69
# 11                  Moveis           670.18
# 12                   Audio           617.36
# 13  Acessorios_e_Inovacoes           594.58
# 14              Automotivo           570.40
# 15         Ar_e_Ventilacao           309.18
# 16       Casa_e_Construcao           261.52
# 17         Eletroportateis           239.74
# 18                Pet_Shop           236.34
# 19             Ferramentas           228.96
# ...

# %%
vendas_correto["mes"]=vendas_correto["Data"].dt.month
vendas_correto
# Out:
# <ipython-input-43-012421e60a10>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vendas_correto["mes"]=vendas_correto["Data"].dt.month
#        idcompra idcanalvenda bandeira       Data     Preço  Preço_com_frete  \
# 1        411885       Mobile        A 2023-03-17   679.200          679.200
# 2        437305       Mobile        A 2023-03-06    35.920           37.512
# 3        440055   Aplicativo        A 2023-01-13  2239.416         2239.416
# 4        455795       Mobile        B 2023-03-31  1743.200         1785.112
# 5        456225     Internet        A 2023-03-19  1903.200         1903.200
# ...         ...          ...      ...        ...       ...              ...
# ...

# %%
vendas_correto.groupby("mes").idcompra.nunique().sort_values(ascending=False)
# Out:
# mes
# 3    18982
# 4    18297
# 1    18159
# 2    17332
# Name: idcompra, dtype: int64

# %%
vendas_correto["mes"] = vendas_correto["Data"].dt.month
vendas_correto.head()
# Out:
# <ipython-input-47-7c8346fa716f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vendas_correto["mes"] = vendas_correto["Data"].dt.month
#    idcompra idcanalvenda bandeira       Data     Preço  Preço_com_frete  \
# 1    411885       Mobile        A 2023-03-17   679.200          679.200
# 2    437305       Mobile        A 2023-03-06    35.920           37.512
# 3    440055   Aplicativo        A 2023-01-13  2239.416         2239.416
# 4    455795       Mobile        B 2023-03-31  1743.200         1785.112
# 5    456225     Internet        A 2023-03-19  1903.200         1903.200
#
#        Nome_Departamento estado  cliente_Log   Frete  mes
# 1                Tablets     SP        17590   0.000    3
# ...

# %%
vendas_correto.groupby("mes").idcompra.nunique().sort_values(ascending=False)
# Out:
# mes
# 3    18982
# 4    18297
# 1    18159
# 2    17332
# Name: idcompra, dtype: int64

# %%
cliente = pd.read_excel("/content/cliente_varejo.xlsx")
cliente.head()
# Out:
#    cliente_Log  idade  renda
# 0        15042     89  11337
# 1        17590     54   2050
# 2        15478     47   8258
# 3         2933     39   4671
# 4        19790     26   9207

# %%
cliente = pd.read_excel("cliente_varejo.xlsx")
cliente.head()
# Out:
#    cliente_Log  idade  renda
# 0        15042     89  11337
# 1        17590     54   2050
# 2        15478     47   8258
# 3         2933     39   4671
# 4        19790     26   9207

# %%
vendas_correto.head()
# Out:
#    idcompra idcanalvenda bandeira       Data     Preço  Preço_com_frete  \
# 1    411885       Mobile        A 2023-03-17   679.200          679.200
# 2    437305       Mobile        A 2023-03-06    35.920           37.512
# 3    440055   Aplicativo        A 2023-01-13  2239.416         2239.416
# 4    455795       Mobile        B 2023-03-31  1743.200         1785.112
# 5    456225     Internet        A 2023-03-19  1903.200         1903.200
#
#        Nome_Departamento estado  cliente_Log   Frete  mes
# 1                Tablets     SP        17590   0.000    3
# 2                  Bebes     SP        15478   1.592    3
# 3       TVs_e_Acessorios     SP         2933   0.000    1
# 4        Esporte_e_Lazer     RS        19790  41.912    3
# 5  Telefones_e_Celulares     SP        23742   0.000    3

# %%
cliente[["idade", "renda"]].describe()
# Out:
#               idade         renda
# count  26425.000000  26425.000000
# mean      53.412564   8241.470350
# std       20.698825   3899.871482
# min       18.000000   1500.000000
# 25%       35.000000   4859.000000
# 50%       53.000000   8234.000000
# 75%       71.000000  11629.000000
# max       89.000000  15000.000000

# %%
cliente.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26425 entries, 0 to 26424
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   cliente_Log  26425 non-null  int64
#  1   idade        26425 non-null  int64
#  2   renda        26425 non-null  int64
# dtypes: int64(3)
# memory usage: 619.5 KB

# %%
cliente = cliente.astype({"renda":float})

# %%
cliente.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26425 entries, 0 to 26424
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   cliente_Log  26425 non-null  int64
#  1   idade        26425 non-null  int64
#  2   renda        26425 non-null  float64
# dtypes: float64(1), int64(2)
# memory usage: 619.5 KB

# %%
cliente = cliente.astype({"renda":"float"})
cliente.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26425 entries, 0 to 26424
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   cliente_Log  26425 non-null  int64
#  1   idade        26425 non-null  int64
#  2   renda        26425 non-null  float64
# dtypes: float64(1), int64(2)
# memory usage: 619.5 KB

# %%
vendas_cliente = vendas_correto.merge(cliente, how="left", on="cliente_Log")

# %%
vendas_cliente = vendas_correto.merge(cliente, how= "left", on="cliente_Log")
vendas_cliente.head()
# Out:
#    idcompra idcanalvenda bandeira       Data     Preço  Preço_com_frete  \
# 0    411885       Mobile        A 2023-03-17   679.200          679.200
# 1    437305       Mobile        A 2023-03-06    35.920           37.512
# 2    440055   Aplicativo        A 2023-01-13  2239.416         2239.416
# 3    440055   Aplicativo        A 2023-01-13  2239.416         2239.416
# 4    455795       Mobile        B 2023-03-31  1743.200         1785.112
#
#   Nome_Departamento estado  cliente_Log   Frete  mes  idade    renda
# 0           Tablets     SP        17590   0.000    3     54   2050.0
# 1             Bebes     SP        15478   1.592    3     47   8258.0
# 2  TVs_e_Acessorios     SP         2933   0.000    1     39   4671.0
# 3  TVs_e_Acessorios     SP         2933   0.000    1     53  11717.0
# 4   Esporte_e_Lazer     RS        19790  41.912    3     26   9207.0

# %%
agg_id_canal_renda = vendas_cliente.groupby("bandeira").idade.agg("mean")
agg_id_canal_renda
# Out:
# bandeira
# A    53.448492
# B    53.387319
# Name: idade, dtype: float64

# %%
agg_idcanal_renda = round(vendas_cliente.groupby("idcanalvenda")["renda"].agg("mean").sort_values(ascending=False).reset_index(),2)
agg_idcanal_renda
# Out:
#   idcanalvenda    renda
# 0   Aplicativo  8239.52
# 1     Internet  8236.37
# 2       Mobile  8233.43

# %%
agg_idade_bandeira = round(vendas_cliente.groupby("bandeira")["idade"].agg("mean").sort_values(ascending=False).reset_index(),2)
agg_idade_bandeira
# Out:
#   bandeira  idade
# 0        A  53.45
# 1        B  53.39

# %%
import matplotlib.pyplot as plt

fig= plt.figure(figsize=(10,2))
plt.bar(agg_idade_bandeira.bandeira,agg_idade_bandeira.idade, color="green")

plt.ylabel("Média de idade")
plt.xlabel("Bandeira")

plt.title("idade por bandeira")
plt.show()

# %%
fig = plt.figure(figsize=(10,8))
plt.bar(agg_idcanal_renda["idcanalvenda"], agg_idcanal_renda["renda"], color="green")
plt.xlabel("canal de venda")
plt.ylabel("renda")
plt.title("renda por canal de venda")
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(7,4))

plt.bar(agg_idade_bandeira["bandeira"], agg_idade_bandeira["idade"], color="green")

plt.ylabel("Média de idade")

plt.title("Idade média por Bandeira", loc="center", fontsize=18, fontweight="bold", color= "black");

# %%
fig = plt.figure(figsize=(7,4))

plt.bar(agg_idcanal_renda["idcanalvenda"], agg_idcanal_renda["renda"], color="green")

plt.ylabel("Renda média")

plt.title("Renda média por canal de venda", loc="center", fontsize=18, fontweight="bold", color="black");

# %%
vendas_por_data=vendas_correto.groupby("Data").idcompra.nunique().reset_index()

# %%
venda_por_data = vendas_correto.groupby("Data").idcompra.nunique().reset_index()
venda_por_data
# Out:
#           Data  idcompra
# 0   2023-01-02       665
# 1   2023-01-03       607
# 2   2023-01-04       677
# 3   2023-01-05       669
# 4   2023-01-06       673
# ..         ...       ...
# 114 2023-04-26       696
# 115 2023-04-27       711
# 116 2023-04-28       651
# 117 2023-04-29       682
# 118 2023-04-30       668
#
# [119 rows x 2 columns]

# %%
fig = plt.figure(figsize=(20,10))
plt.xlabel("data")
plt.ylabel("número de vendas")
x=venda_por_data["Data"]
y=venda_por_data["idcompra"]

plt.plot(x,y)

# %%
fig = plt.figure(figsize=(20,12))


plt.xlabel("Data da venda")
plt.ylabel("Quantidade de vendas")
x = venda_por_data["Data"]
y = venda_por_data["idcompra"]

plt.plot(x,y, color = "green", linewidth = "2")
plt.show()

# %%
agg_dept_preco = round(vendas_correto.groupby("Nome_Departamento")["Preço_com_frete"].agg("mean").sort_values(ascending=False).reset_index(),2)
agg_dept_preco

fig = plt.figure(figsize=(20,20))
plt.xticks(rotation=45, ha='right')

plt.bar(agg_dept_preco["Nome_Departamento"],agg_dept_preco["Preço_com_frete"])
plt.show()

# %%
px.bar(agg_dept_preco,x="Nome_Departamento",y="Preço_com_frete")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = plt.figure(figsize=(30,20))

plt.bar(agg_dept_preco["Nome_Departamento"], agg_dept_preco["Preço_com_frete"], color="green")

plt.ylabel("Preço médio")

plt.title("Preço médio por departamento", loc="center", fontsize=18, fontweight="bold", color="black");

# %%
# %pip install plotly
# %pip install cufflinks
# %pip install chart-studio

# %%
import chart_studio.plotly as py
import cufflinks as cf

import plotly.graph_objects as go
import plotly.express as px

# %%
px.bar(agg_idade_bandeira,x="bandeira",y="idade")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.line(venda_por_data,x = venda_por_data["Data"],y = venda_por_data["idcompra"])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.bar(agg_idade_bandeira, x = "bandeira", y = "idade")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.line(venda_por_data, x= "Data", y="idcompra")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
agg_dept_preco
# Out:
#          Nome_Departamento  Preço_com_frete
# 0               TV_e_Video          9847.26
# 1         TVs_e_Acessorios          2058.70
# 2              Informatica          2018.26
# 3         Linha_Industrial          1668.68
# 4              Cine_e_Foto          1461.08
# 5    Telefones_e_Celulares          1420.01
# 6         Eletrodomesticos          1235.42
# 7          Esporte_e_Lazer          1032.47
# 8                  Tablets           963.60
# 9    Instrumentos_Musicais           834.61
# 10                   Games           739.69
# 11                  Moveis           670.18
# 12                   Audio           617.36
# 13  Acessorios_e_Inovacoes           594.58
# 14              Automotivo           570.40
# 15         Ar_e_Ventilacao           309.18
# 16       Casa_e_Construcao           261.52
# 17         Eletroportateis           239.74
# 18                Pet_Shop           236.34
# 19             Ferramentas           228.96
# ...

# %%
px.bar(agg_dept_preco, x="Nome_Departamento", y="Preço_com_frete")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
